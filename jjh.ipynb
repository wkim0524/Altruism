# %%
import selenium 
from selenium import webdriver
from bs4 import BeautifulSoup

x=0
while x < 40: #조건문 시작. 필요에 따라 수정 
    x = (10*x) + 1 #x 값 정의
    z = str(x) #x 값 스트링으로 변환. 밑의 주소에 입력시 int 는 입력이 안되어 str로 변환

# %%
        #텍스트 리스트 만들기
texts = []
        
html = 'https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=간이과세&c_id=&c_name=&sm=tab_pge&kin_start=' #소스 페이지    
driver = webdriver.Chrome('/Users/stan/chromedriver') #드라이버 실행. 크롬 사용. 다른 드라이버 사용 가능
            
driver.get(html + z) #html 과 z 를 조합한 주소로 크롬 실행
            
            #상위 엘리먼트 객체 불러오기
results = driver.find_elements_by_css_selector('dt.question') #li 태그가 붙은 부위 results 로 묶음
        
links = [] #새창에 띄울 링크 리스트 생성

# %%
xpath = driver.find_element_by_xpath('//*[@id="elThumbnailResultArea"]/li[1]/dl/dt/a')

# %%
xpath
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ae224c55673f968f399ef34300532269", element="0.27695536118663533-141")>

# %%
results
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5249f916d788e65ab04e3a89e72ab262", element="0.5852112841197299-10")>]

# %%
         
            #li 객체에서 a 태그가 붙은 객체 중, href 를 포함하는 객체를 포함하기
for i in range(0,9): #li 태그 객체중 19번 부터 31번 까지만 필요로 하기 떄문에 range 설정
    link = results[i].find_element_by_tag_name("a") #results, 즉 li 태그가 붙은 19~31 번 객체로 부터, a 태그가 붙은 위치 link 로 정의
    links.append(link.get_attribute("href")) # a 태그 가 붙은 링크가 포함하고 있음 href 항목을 links 리스트에 저장

# %%
link
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="903d83aef219609c709db6f221b7d9e6", element="0.1025338234556874-326")>

# %%
links
# Out:
# ['https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40304&docId=293714318&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=111&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=6&dirId=60105&docId=313003782&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=112&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40309&docId=303284548&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=113&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40309&docId=306042056&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=114&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40309&docId=290161459&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=115&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40309&docId=292916020&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=116&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=403&docId=296754883&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=117&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40306&docId=294196727&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=118&search_sort=0&spq=0',
#  'https://kin.naver.com/qna/detail.nhn?d1id=4&dirId=40309&docId=301454469&qb=6rCE7J206rO87IS4&enc=utf8&section=kin&rank=119&search_sort=0&spq=0']

# %%
      
            #새탭에 전부 출력
        for link in links: #links 리스트의 모든 link 를
            driver.execute_script('window.open("'+link+'")') #새로운 창에서 실행

# %%
     
        driver.switch_to.window(driver.window_handles[0]) # 창 변경
            #크롤링
        html = driver.page_source #창페이지 소스 긁어오기
        soup = BeautifulSoup(html, 'html.parser') #소스 파싱
        body = soup.select('div.question-content') #범위 셀렉트
        texts.append(body) #리스트에 추출 텍스트 저장
            
            ###
        driver.switch_to.window(driver.window_handles[1]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
        
            ###
        driver.switch_to.window(driver.window_handles[2]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[3]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[4]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[5]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[6]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[7]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[8]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)
            
            ###
        driver.switch_to.window(driver.window_handles[9]) # 창 변경
            #크롤링
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        body = soup.select('div.question-content')
        texts.append(body)

# %%
texts
# Out:
# [[], [], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									개인사업자(간이과세)인테 의료보험 따로 나오나요?
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   <p>단독 상속으로 상가를 받아 개인사업자( 간이과세)가 되었어요.부동산 임대(3천에 50)를 주었구요.</p><p> 남편밑에 있다가 사업자가 되어서 부양자에서 빠졌는데 의료보험도 따로 내야 하나요?</p>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40306" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">취득세, 등록세</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url('https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m/2.png');"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">1</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">100.0%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">100.0%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>yeon****</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.02.04.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40306, 294196727, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<p class="popup__title_text"><span class="ico_alert sp_common"></span>권장 브라우저 안내</p>,
#   <p class="popup__text">혹시 아직 인터넷 익스플로러 9.0 미만 버전을 사용하고 계신가요?</p>,
#   <p class="popup__subtext">새롭게 바뀐 지식iN Q&amp;A 페이지는 IE 9.0 이상의 브라우저에 최적화되어 있습니다. 원활한 이용을 위해 꼭 업데이트 해주세요! <a class="popup__link" href="https://support.microsoft.com/ko-kr/help/17621/internet-explorer-downloads" target="_blank">업데이트하기 <span class="sp_common ico_arr_lnk"></span></a></p>,
#   <p class="gnb_account"><span class="gnb_name" id="gnb_name2"><a class="gnb_nick" href="https://nid.naver.com/user2/api/naverProfile.nhn?m=checkIdType">_</a>님</span><a class="gnb_btn_login" href="https://nid.naver.com/nidlogin.logout?returl=https%3A%2F%2Fnid.naver.com%2Fnidlogin.logout" id="gnb_logout_button"><span class="gnb_bg"></span><span class="gnb_bdr"></span><span class="gnb_txt">로그아웃</span></a></p>,
#   <p class="gnb_pay_check" id="gnb_pay_check"><em>N Pay</em><a href="http://pay.naver.com" id="gnb_pay_point"><span>내 페이포인트</span></a></p>,
#   <p class="gnb_msg"><strong>알림을 모두 삭제하시겠습니까?</strong></p>,
#   <p>단독 상속으로 상가를 받아 개인사업자( 간이과세)가 되었어요.부동산 임대(3천에 50)를 주었구요.</p>,
#   <p> 남편밑에 있다가 사업자가 되어서 부양자에서 빠졌는데 의료보험도 따로 내야 하나요?</p>,
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>,
#   <p class="title"><a href="/profile/index.nhn?u=hLDUz8QzHdhq%2BJMrdD%2BAaGRKwNvh6XNemoLDa7BQWCY%3D" onclick="naver.kin.pc.common.nClicks('end*a.profile', '', '', event);" target="_blank">세무맨님 답변</a></p>,
#   <p><span style="">안녕하세요..</span></p>,
#   <p><br/></p>,
#   <p><span style="">상가를 상속받은 경우에는 상가임대수입에 대한 사업자등록을 하여야 합니다.</span></p>,
#   <p><span style="">그러한 경우에는 의료보험도 지역으료보험에 가입되어야 하리라고 봅니다만,</span></p>,
#   <p><span style="">그에 대하여는 의료보험공단에 전화로 문의하면 정확한 내용을 알려줍니다.</span></p>,
#   <p><span style="">참고가 되었으면 좋겠습니다</span>.</p>,
#   <p class="c-guideline__desc">본 답변은 참고 용도로만 활용 가능하며 정확한 정보는 관련기관에서 확인해보시기 바랍니다.</p>,
#   <p class="c-heading-answer__content-date">2018.02.05.</p>,
#   <p><em>분야</em><span class="blind">경제</span></p>,
#   <p><em>열심</em></p>,
#   <p class="popup__item_subtext">2018.10.17.</p>,
#   <p class="popup__item_subtext">2018.10.17.</p>,
#   <p class="popup__item_subtext">2018.04.26.</p>,
#   <p class="popup__item_subtext">2018.04.26.</p>,
#   <p class="popup__text">현재 비공개 설정된 질문입니다.</p>,
#   <p class="popup__subtext">다시 공개 질문으로 변경하시겠습니까?</p>,
#   <p class="popup__confirm_text">계속 진행하시겠습니까?</p>,
#   <p class="popup__confirm_text">
#   <label class="popup__label">
#   <input class="popup__checkbox blind _closeUserIdCheck" type="checkbox"/><i class="popup__label_check"></i>
#   							질문 목록에서 제외하겠습니다.
#   						</label>
#   </p>,
#   <p class="popup__confirm_text"><label class="popup__label">계속 진행하시겠습니까?</label></p>,
#   <p class="popup__confirm_text"><label class="popup__label">계속 진행하시겠습니까?</label></p>,
#   <p class="layer_text">
#   						추가질문하시면<br/><em class="highlight_blue _userText"></em>님께 받은 답변이<br/>함께 채택됩니다.
#   					</p>,
#   <p class="layer_sub_text">
#   						채택으로 고마움을 같이 표현하고,<br/>더 알고 싶은 궁금증도 해결해보세요.
#   					</p>,
#   <p class="copyright"><a class="footer_logo sp_common" href="http://www.naver.com" target="_blank">NAVER</a>Copyright © <strong><a class="logo _nclicks:fot.nhncorp" href="http://www.navercorp.com" target="_openNHNWindow">NAVER Corp.</a></strong> All Rights Reserved.</p>], [], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									개인사업자(간이과세)인테 의료보험 따로 나오나요?
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   <p>단독 상속으로 상가를 받아 개인사업자( 간이과세)가 되었어요.부동산 임대(3천에 50)를 주었구요.</p><p> 남편밑에 있다가 사업자가 되어서 부양자에서 빠졌는데 의료보험도 따로 내야 하나요?</p>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40306" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">취득세, 등록세</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url('https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m/2.png');"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">1</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">100.0%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">100.0%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>yeon****</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.02.04.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40306, 294196727, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old" data-tag="%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8,%EC%A2%85%ED%95%A9%EC%86%8C%EB%93%9D%EC%84%B8,%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90,%EC%87%BC%ED%95%91%EB%AA%B0%EC%B0%BD%EC%97%85,%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EC%A2%85%ED%95%A9%EC%86%8C%EB%93%9D%EC%84%B8,%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EC%8B%A0%EA%B3%A0,%EC%82%AC%EC%97%85%EC%9E%90%EC%B9%B4%EB%93%9C,%EA%B0%84%EC%9D%B4%EC%82%AC%EC%97%85%EC%9E%90%EC%84%B8%EA%B8%88%EC%8B%A0%EA%B3%A0">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									블로그마켓 간이과세 사업자등록 후 세금과 카드에 대하여 질문드립니다
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   <p>- 소득세<br/>- 부가가치세</p><p><br/></p><p>안녕하세요</p><p>블로그마켓을 운영해보려고 어제 사업자등록을 간이과세자로 하고</p><p>오늘 은행가서 사업자통장만들고 통신판매업신고까지 마쳤습니다.</p><p>인터넷 뒤져봐도 모든게 처음인지라 모르는 말 투성이고 이해가 잘 안가서 지식인에 질문해요</p><p>도와주시면 정말 감사하겠습니다 .. ㅠㅠ</p><p>주로 의류를 판매할거구요 매출이 조금 나온다면 도메인을 사서 쇼핑몰을 정식으로 열려고 해요.</p><p><br/></p><p>질문1. 사업자통장을 만들었는데 체크카드는 아직 안만들었어요.</p><p>카드를 만들어서 동대문갈때 쓰는 경비라던지 사업에 필요한 걸 샀을 때 나가는 지출경비</p><p>증빙할려고 하는데 친구는 간이사업자는 그런거 필요없다면서 그러네요 .. 뭐가 맞는걸까요</p><p><br/></p><p>질문2. 세금에 대하여 정말 아무것도 모르는데요. 부가가치세라던지 종합소득세라던지</p><p>알기 쉽게 설명해주시면 정말 감사하겠습니다 ㅠㅠ</p><p><br/></p><p>질문3. 만약 어플이나 동대문에 가서 옷을 사입해오면 영수증을 받아야 할텐데</p><p>간이사업자는 세금계산서나 그런거 필요없이 장끼라고들 말하는 그 영수증만 모아놓으면 되는건가요?</p><p>제가 찾아본 결과 간이사업자는 세금계산서를 부가가치세 10프로를 주고 받으면 손해라고 하는데</p><p>옷을 매입했을 때 증명을 해야될텐데 뭘로 해야되나요? 그게 소득세 신고할 때 필요하다하는데..</p><p><br/></p><p>알려주시면 정말 정말 감사하겠습니다 ㅠㅠ</p><p></p>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>부가가치세</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%A2%85%ED%95%A9%EC%86%8C%EB%93%9D%EC%84%B8&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>종합소득세</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이과세자</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%87%BC%ED%95%91%EB%AA%B0%EC%B0%BD%EC%97%85&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>쇼핑몰창업</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EC%A2%85%ED%95%A9%EC%86%8C%EB%93%9D%EC%84%B8&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이과세자종합소득세</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EA%B0%80%EC%B9%98%EC%84%B8%EC%8B%A0%EA%B3%A0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이과세자부가가치세신고</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%82%AC%EC%97%85%EC%9E%90%EC%B9%B4%EB%93%9C&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>사업자카드</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EC%82%AC%EC%97%85%EC%9E%90%EC%84%B8%EA%B8%88%EC%8B%A0%EA%B3%A0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이사업자세금신고</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">2</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">100.0%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">100.0%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.05.15.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 301454469, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									개인사업자(간이과세)인테 의료보험 따로 나오나요?
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   <p>단독 상속으로 상가를 받아 개인사업자( 간이과세)가 되었어요.부동산 임대(3천에 50)를 주었구요.</p><p> 남편밑에 있다가 사업자가 되어서 부양자에서 빠졌는데 의료보험도 따로 내야 하나요?</p>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40306" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">취득세, 등록세</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url('https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m/2.png');"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">1</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">100.0%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">100.0%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>yeon****</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.02.04.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40306, 294196727, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									면세사업자 간이과세사업자 세금 언제 내야되는건가요
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						면세사업자 간이과세사업자 세금 언제 내야되는건가요<br/>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=403" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금, 세무</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">71</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">93.3%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">95.0%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.03.08.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(403, 296754883, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									일반과세 간이과세
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						일반과세자랑 간이과세자 중에 첫스타트 창업하는데 매출보다 매입이 많을것같은데 어떤걸로 하는게 좋아요??<br/>간이과세자로 하면 세금은 적게내지만 초기 지출비용이랑 매입비용에 대해서 세금도 못돌려받는게 걸려서요..<br/>세금영수증도 못받고 되려 상대한테도 발급을 못하는건지요?<br/><br/>그리고 사업자 등록 하고 나서 가족들이 그 사업자 명의로 현금영수증 할때 사소한 영수증들도 다 갖고 있어야 하나요 아니면 사업에 썼던 사업에 관련된 영수증만 있어야 하나요??
#   					</div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">53</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">67.4%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">67.4%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.01.19.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 292916020, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#   									택배기사 간이과세로 등록 가능한가요<br/>월350정도 되구요 1년됐어요
#
#
#
#   						</div>
#   </div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">144</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">83.3%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">84.2%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2017.12.12.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 290161459, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--multiple">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#   									지금 제가 간이과세로 고깃집운영중입니다.<br/>근데 신혼집 리모델링 하려고 하는데 현금영수증이 안되고 세금계산서만 가능하다고 하는데 신혼집 리모델링한 세금계산서를 가게세금계산서로 쓸수있을까요??
#
#
#
#   						</div>
#   </div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">40</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">94.3%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">94.3%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.07.21.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 306042056, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old" data-tag="%EC%84%B8%EA%B8%88,%EC%87%BC%ED%95%91%EB%AA%B0,%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EC%84%B8%EC%8B%A0%EA%B3%A0">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									쇼핑몰 간이과세 부가세 질문
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						의류 쇼핑몰을 오늘 오픈하였습니다.<div>매출아직 없는 상태구요</div><div>세금에 대해서 아는게 너무 없어서 기본적인 질문들 몇가지 남깁니다 </div><div><br/></div><div>1. 사입으로 쓰는 지출. 동대문에서 매달 말일에 세금계산서를해주는데</div><div>간이과세는 세금계산서 발행이 안된다고 들었습니다. 그럼 안해도 되는건가요?</div><div>그럼 저희의 사입으로 나가는 지출은 어떻게 증빙을하나요? 부가세10%가 들어가지않은</div><div>사입장끼만으로도 가능한가요?</div><div><br/></div><div>2. 간이과세는 영수증을 열심히 모으라는 말을 들었습니다 (+현금영수증,종이영수증)</div><div>현금영수증이야 자동으로 거래가 등록이 될 것이고 , 종이 영수증으로느 어떻게 증빙할 수 있는지 알고싶습니다.</div><div><br/></div><div>3. 신고기간이 언제일까요</div><div><br/></div><div>4. 첫 투자금이 1000만원이라면 지출이 어느정도 나와야 세금폭탄을 안맞을까요?</div><div><br/></div><div>5. 종합소득세와 부가세신고 뭐가 다른가요 ㅠㅠ 둘다 저희가 신고해야하는 것들인가요?</div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%84%B8%EA%B8%88&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>세금</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%87%BC%ED%95%91%EB%AA%B0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>쇼핑몰</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EC%84%B8%EC%8B%A0%EA%B3%A0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이과세자부가세신고</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">26</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">93.8%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">93.8%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.06.11.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 303284548, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <span class="c-heading__icon-square">FAQ</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									간이과세 포기신청
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						간이과세사업자로 전환된다는 통지를 받았습니다. 세금계산서를 계속 발급해야 하는데 간이사업자를 포기할 수 있는지요?
#   					</div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=60105" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">국민신문고</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.06.26.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <div class="c-userinfo__button-setting" role="presentation">
# ...
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--multiple">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#   									지금 제가 간이과세로 고깃집운영중입니다.<br/>근데 신혼집 리모델링 하려고 하는데 현금영수증이 안되고 세금계산서만 가능하다고 하는데 신혼집 리모델링한 세금계산서를 가게세금계산서로 쓸수있을까요??
#
#
#
#   						</div>
#   </div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">40</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">94.3%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">94.3%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.07.21.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 306042056, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old" data-tag="%EC%84%B8%EA%B8%88,%EC%87%BC%ED%95%91%EB%AA%B0,%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EC%84%B8%EC%8B%A0%EA%B3%A0">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									쇼핑몰 간이과세 부가세 질문
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						의류 쇼핑몰을 오늘 오픈하였습니다.<div>매출아직 없는 상태구요</div><div>세금에 대해서 아는게 너무 없어서 기본적인 질문들 몇가지 남깁니다 </div><div><br/></div><div>1. 사입으로 쓰는 지출. 동대문에서 매달 말일에 세금계산서를해주는데</div><div>간이과세는 세금계산서 발행이 안된다고 들었습니다. 그럼 안해도 되는건가요?</div><div>그럼 저희의 사입으로 나가는 지출은 어떻게 증빙을하나요? 부가세10%가 들어가지않은</div><div>사입장끼만으로도 가능한가요?</div><div><br/></div><div>2. 간이과세는 영수증을 열심히 모으라는 말을 들었습니다 (+현금영수증,종이영수증)</div><div>현금영수증이야 자동으로 거래가 등록이 될 것이고 , 종이 영수증으로느 어떻게 증빙할 수 있는지 알고싶습니다.</div><div><br/></div><div>3. 신고기간이 언제일까요</div><div><br/></div><div>4. 첫 투자금이 1000만원이라면 지출이 어느정도 나와야 세금폭탄을 안맞을까요?</div><div><br/></div><div>5. 종합소득세와 부가세신고 뭐가 다른가요 ㅠㅠ 둘다 저희가 신고해야하는 것들인가요?</div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40309" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">세금 정책, 제도</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%84%B8%EA%B8%88&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>세금</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EC%87%BC%ED%95%91%EB%AA%B0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>쇼핑몰</a>
#   <a class="tag-list__item" href="/tag/tagDetail.nhn?tag=%EA%B0%84%EC%9D%B4%EA%B3%BC%EC%84%B8%EC%9E%90%EB%B6%80%EA%B0%80%EC%84%B8%EC%8B%A0%EA%B3%A0&amp;listType=answer" onclick="naver.kin.pc.common.nClicks('end*q.tag', '', '', event);" role="listitem" target="_blank"><span>#</span>간이과세자부가세신고</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">26</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">93.8%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">93.8%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.06.11.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40309, 303284548, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--default-old">
#   <div class="c-heading__icon">
#   <span class="c-heading__icon-square">FAQ</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#
#   									간이과세 포기신청
#
#
#   						</div>
#   </div>
#   </div>
#   <div class="c-heading__content">
#   						간이과세사업자로 전환된다는 통지를 받았습니다. 세금계산서를 계속 발급해야 하는데 간이사업자를 포기할 수 있는지요?
#   					</div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=60105" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">국민신문고</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.06.26.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option" style="display: none;"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>], [<div class="question-content">
#   <div class="question-content__inner _contentWrap">
#   <div class="c-heading _questionContentsArea c-heading--multiple">
#   <div class="c-heading__icon">
#   <i aria-hidden="true" class="icon icon_common_q"></i><span class="blind">질문</span>
#   </div>
#   <div class="c-heading__title">
#   <div class="c-heading__title-inner">
#   <div class="title">
#
#
#
#   									간이과세 부가가치세 신고기간 지난후에 <br/>1월 25일까지 신고기간이라고했는데 못했습니다. 매출이 2000도 안되고 몇달후에 폐업신고를 할 예정이라서 어떻게 해야하는건가요? 기간이 지나서도 신고가능한가요? 폐업신고할때 문제생길까요?
#
#
#
#   						</div>
#   </div>
#   </div>
#   </div>
#   <div class="tag-list tag-list--end-title" role="list">
#   <a class="tag-list__item tag-list__item--category" href="/qna/kinupList.nhn?dirId=40304" onclick="naver.kin.pc.common.nClicks('end*q.category', '', '', event);" role="listitem" target="_blank">부가가치세</a>
#   </div>
#   <div class="c-userinfo">
#   <div class="c-userinfo__left">
#   <div class="c-userinfo__profile _profileArea">
#   <div class="profile-default">
#   <div class="profile-default--inner">
#   <span class="profile-default__thumbnail" style="background-image: url(https://ssl.pstatic.net/static/kin/09renewal/avatar/200x200_m_gray/public.png);"><span class="blind">내 프로필 이미지</span></span>
#   </div>
#   <div class="c-callout callout--profile-tooltip _profileTooltip">
#   <ul class="c-callout__list">
#   <li class="c-callout__item"><strong class="c-callout__item-title">질문수</strong><span class="c-callout__item-count">42</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">채택률</strong><span class="c-callout__item-count">81.6%</span></li>
#   <li class="c-callout__item"><strong class="c-callout__item-title">마감률</strong><span class="c-callout__item-count">86.8%</span></li>
#   </ul>
#   </div>
#   </div>
#   <span class="c-userinfo__author"><span class="blind">닉네임</span>비공개</span>
#   </div>
#   <span class="c-userinfo__date"><span class="blind">작성일</span>2018.01.29.</span>
#   </div>
#   <div class="c-userinfo__right" role="listbox">
#   <a aria-selected="false" class="button_compose _commentBtn" href="#" id="cmtstr_0" onclick="naver.kin.pc.common.nClicks('end*q.comm', '', '', event);" role="option">
#   <i aria-hidden="true" class="icon icon_compose_opinion"></i>
#   <span class="blind">댓글</span>
#   <em class="button_compose_count _commentCnt" style="display: none;"></em>
#   </a>
#   <a aria-selected="false" class="button_compose is_disabled _disable" href="#" id="metooWonderBtn" onclick="naver.kin.pc.common.nClicks('end*q.metoo', '', '', event);return false;" role="option">
#   <i aria-hidden="true" class="icon icon_compose_wonder"></i>
#   <span class="blind">나도 궁금해요</span>
#   <em class="button_compose_count _metooWonderCnt">
#   </em>
#   </a>
#   <div class="popup popup--w300 popup--bottom popup--right _metooWonderLayer _popupLayer" style="display: none;">
#   <strong class="popup__title">'나도 궁금해요'한 질문에 대한 소식을 알려드립니다.</strong>
#   <p class="popup__text">프로필 &gt; 나도 궁금해요에 보관됩니다.</p>
#   <div class="popup__button_area">
#   <a class="c-button-default popup__button_cancel _metooWonderLayerCloseBtn" href="#" role="button">
#   <span class="c-button-default__title">닫기</span>
#   </a>
#   <a class="c-button-default popup__button_submit" href="/myinfo/metooWonderList.nhn" role="button">
#   <span class="c-button-default__title">나도 궁금해요 확인하기</span>
#   </a>
#   </div>
#   </div>
#   <div class="c-userinfo__button-setting" role="presentation">
#   <a aria-expanded="false" aria-haspopup="true" aria-selected="false" class="button_compose _questionMenuLayerButton" href="#" id="questionMenuBtn" onclick="naver.kin.pc.common.nClicks('end*q.more', '', '', event);" role="option"><i aria-hidden="true" class="icon icon_compose_setting _questionMenuLayerButton"></i><span class="blind">더보기</span></a>
#   <div aria-hidden="true" class="c-userinfo__list-setting _questionMenuLayer _popupLayer" role="listbox">
#   <a class="_ros c-userinfo__setting-item _questionMenuButton" href="#" id="opt_2" onclick="naver.kin.pc.common.nClicks('end*q.qreport', '', '', event);reportAnswer(40304, 293714318, 0, '');return false;" role="option">신고</a>
#   </div>
#   </div>
#   </div>
#   </div>
#   <div class="c-opinion _commentListArea" data-answer-no="0" style="display:none;"></div>
#   </div>
#   </div>]]

# %%
          
        driver.quit() #드라이버 종료
        
        if z is '0': #첫페이지 실행시
            f = open("testing123.txt","w+") #파일생성 및 쓰기
            print(texts, file=f) #texts 에 저장된 리스트 파일에 쓰기
        else: #첫페이지 후에 오픈되는 페이지
            f = open("testing123.txt", "a+") #기존 파일 열고 추가 하기
            print(texts, file=f) #text 에 저장된 리스트 파일에 추가
                

        #while 문 조건 제한 부분. 필요에 따라 수정 가능
        if x < 5: 
            continue
        if x > 6:
            break
