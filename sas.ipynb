# %%
import konlpy

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("quantdata.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 1</th>
#       <th>대중교통</th>
#       <th>Unnamed: 3</th>
#       <th>Unnamed: 4</th>
#       <th>Unnamed: 5</th>
#       <th>Unnamed: 6</th>
#       <th>Unnamed: 7</th>
#       <th>Unnamed: 8</th>
#       <th>Unnamed: 9</th>
#       <th>...</th>
#       <th>Unnamed: 41</th>
#       <th>Unnamed: 42</th>
#       <th>Unnamed: 43</th>
#       <th>Maas</th>
#       <th>Unnamed: 45</th>
#       <th>Unnamed: 46</th>
#       <th>Unnamed: 47</th>
#       <th>기타</th>
#       <th>Unnamed: 49</th>
#       <th>Unnamed: 50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>지하철</td>
#       <td>NaN</td>
#       <td>버스</td>
#       <td>NaN</td>
#       <td>택시</td>
#       <td>NaN</td>
#       <td>좌석버스</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>일행이 있을때</td>
#       <td>NaN</td>
#       <td>교통환경에 변화</td>
#       <td>교통수단선택</td>
#       <td>기대하는 변화</td>
#       <td>수용가능 가격대</td>
#       <td>해외 교통수단과 비교</td>
#       <td>자차이용행태변화</td>
#       <td>대중교통에게 기대하는 점</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>선호</td>
#       <td>비선호</td>
#       <td>선호</td>
#       <td>비선호</td>
#       <td>선호</td>
#       <td>비선호</td>
#       <td>선호</td>
#       <td>비선호</td>
#       <td>...</td>
#       <td>비선호</td>
#       <td>선호</td>
#       <td>비선호</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>주연</td>
#       <td>1.0</td>
#       <td>(일정속도로 가속, 정차하기 떄문에 서서 가기에는 지하철이 쾌적하고 공간도 넓다.)...</td>
#       <td>지하철 중간에 환승할 때에도 많이 걸어야 함. 앉아서 가지 못함. 지하철은 밖이 안...</td>
#       <td>일반적으로는 버스를 선호한다. 상황이나 목적지에 따라 달라지고 그거에 맞게 이용한다...</td>
#       <td>급정거 급제동 급출발 급차선변경 등 운전 난폭하게 해서 서서가면 피곤(일정속도로 가...</td>
#       <td>시간 촉박하거나 술취했을때나 차 끊겼을 때 주로 탄다. 장거리일 때에도 타나? 거의...</td>
#       <td>택시탈 때 불편한 것 많다. 차량의 정비상태, 청결 포함 관리상태, 택시업에 종사하...</td>
#       <td>지하철 보다도 비싸지만, 광역버스보다도 비싸지만 좌석버스를 탐. 출근 시간대에 겹치...</td>
#       <td>퇴근시에는 좌석 없다 하면 지하철 타러 간다. 출근시간에 비해 퇴근이 2배 더 걸...</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>일행 있을 때에는 지하철 선호한다. 버스에 비해 빨리 도착하고 같이 이야기하면서 가...</td>
#       <td>NaN</td>
#       <td>우리나라는 고정관념이 강하다고 생각한다. 그런 것을 대중교통으로 받아들이는 데에는 ...</td>
#       <td>자전거 셔틀버스 등 구축 되어있어도 출퇴근시에는 활용 안할 것 같다. 셔틀버스 줄서...</td>
#       <td>장비관리가 안돼서 도입되기 어려울 것 같다. 소카 그린카 등도 적자보면서 시장선점 ...</td>
#       <td></td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>이미 시스템 요금 등이 잘 돼있어서 세계에 내놓아도 손색이 없다. 하지만  시설관리...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>2.0</td>
#       <td>지하철 역을 찾기 쉽고, 맵이 머릿 속에 다 들어있어서 길치인 나는 타게된다. 지하...</td>
#       <td>통풍 잘 안돼고 냄새나고 지하에서 위험상황에서 고립된 느낌들것같은 느낌이 있다. 변...</td>
#       <td>버스 노선을 명확히 아는 경우는 자주 탄다. 목적지에서 가까워서 용이하기도 하고. ...</td>
#       <td>버스는 길치라서 버스정류장 찾기가 힘들고 방향도 봐야해서 어렵다. 밀리기도 하고. ...</td>
#       <td>편리해서 자주 이용한다. 차림이나 소지품이 좀 번거로운 경우 장거리도 그냥 택시 타...</td>
#       <td>길을 잘 몰라서 타는데 주소를 잘 안찍어줄 때 불편하다. 카카오택시는 편한데, 아닐...</td>
#       <td>NaN</td>
#       <td></td>
#       <td>...</td>
#       <td>교통수단으로 접근하기 쉬운 곳이나 환승 안해도 되는 곳으로 약속 잡으려고 한다.</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>이동소요 시간을 줄여줄 수 있을 것 같아서 좋다.</td>
#       <td></td>
#       <td></td>
#       <td>정기권 하는 것 보다 저렴하게 시작해서 올리는게 나을 것 같다. 지금 크게 굥통수단...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>3.0</td>
#       <td>지하철 안에서는 음악을 주로 듣고, 지하철 역까지 갔는데 이어폰 안가져오면 집까지 ...</td>
#       <td></td>
#       <td></td>
#       <td>버스는 모든 면에서 지하철보다 별로다. 가면서 할 수 있는게 제한적이다 책읽거나 일...</td>
#       <td>강남에서 집까지 타기도 한다 법카 있을때…!</td>
#       <td>고양이를 키우는데, 승차거부 많이 하셔서 운전면허 땄다. 전용 가방에 넣어서 타도 ...</td>
#       <td>NaN</td>
#       <td>기사님과 눈치게임 해야한다. 최대한 태우기 싫어하신다. 종점 빨리 가면 빨리 퇴근하...</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>3명 이상이면, 일행이 많을 때에는 주로 택시 타서 n빵 한다.</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>중국은 자전거 문화라는 것이 있고, 그 위에 공유자전거가 있는 것이라서 시장이 한국...</td>
#       <td>Maas서비스로 제3의 교통수단이 있고 모든 면에서 통제 예측 가능하다면 요금 2-...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>예측 가능했으면 좋겠다, 유동인구가 얼마나 될 것이고, 온도도 어느정도로 유지될 것...</td>
#     </tr>
#   </tbody>
# </table>
# <p>5 rows × 51 columns</p>
# </div>
